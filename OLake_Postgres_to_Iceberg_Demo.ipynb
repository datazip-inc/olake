# %%
# Install required packages (run once)
# !pip install psycopg2-binary pandas pyarrow pyiceberg

import psycopg2
import pandas as pd
from datetime import datetime

# PostgreSQL connection parameters
PG_CONFIG = {
    'host': 'localhost',
    'port': 5433,
    'database': 'postgres',
    'user': 'postgres',
    'password': 'password'
}

print("✓ Packages imported successfully")
print(f"Connecting to PostgreSQL at {PG_CONFIG['host']}:{PG_CONFIG['port']}")
# Out:
# ✓ Packages imported successfully
# Connecting to PostgreSQL at localhost:5433

# %%
# Connect to PostgreSQL
conn = psycopg2.connect(**PG_CONFIG)
cursor = conn.cursor()

# Get table schema
cursor.execute("""
    SELECT column_name, data_type, character_maximum_length, is_nullable
    FROM information_schema.columns
    WHERE table_name = 'test_cdc' AND table_schema = 'public'
    ORDER BY ordinal_position;
""")

schema_df = pd.DataFrame(
    cursor.fetchall(),
    columns=['Column', 'Data Type', 'Max Length', 'Nullable']
)

print("📊 Source Table Schema:")
print("="*60)
display(schema_df)

# Get row count
cursor.execute("SELECT COUNT(*) FROM test_cdc;")
row_count = cursor.fetchone()[0]
print(f"\n📈 Total rows in source table: {row_count}")
# Out:
# 📊 Source Table Schema:
# ============================================================
#        Column                    Data Type Max Length Nullable
# 0          id                         uuid       None       NO
# 1        data                        jsonb       None       NO
# 2        meta                         json       None      YES
# 3  created_at  timestamp without time zone       None      YES
# 📈 Total rows in source table: 2

# %%
# Query source data
query = """
    SELECT 
        id::text as uuid_id,
        data::text as jsonb_column,
        meta::text as json_column,
        created_at,
        pg_typeof(id) as uuid_type,
        pg_typeof(data) as jsonb_type,
        pg_typeof(meta) as json_type
    FROM test_cdc 
    ORDER BY created_at;
"""

source_df = pd.read_sql_query(query, conn)

print("📋 Source Data Sample:")
print("="*80)
display(source_df)

print("\n🔍 Key Observations:")
print(f"  • UUID column type: {source_df['uuid_type'].iloc[0]}")
print(f"  • JSONB column type: {source_df['jsonb_type'].iloc[0]}")
print(f"  • JSON column type: {source_df['json_type'].iloc[0]}")
print(f"  • These complex types will be properly handled by OLake's pgtype integration")

# Close connection for now
cursor.close()
conn.close()
# Out:
# 📋 Source Data Sample:
# ================================================================================
#                                 uuid_id  \
# 0  e61b23d7-2bed-4594-8243-9d389511c688
# 1  5f199f4c-cc2b-487c-bbb2-612ffa920e17
#
#                             jsonb_column           json_column  \
# 0   {"user": "alice", "action": "login"}     {"source": "web"}
# 1  {"user": "bob", "action": "purchase"}  {"source": "mobile"}
#
#                   created_at uuid_type jsonb_type json_type
# 0 2026-02-07 12:54:30.368422      uuid      jsonb      json
# 1 2026-02-07 12:54:30.368422      uuid      jsonb      json
# 🔍 Key Observations:
#   • UUID column type: uuid
#   • JSONB column type: jsonb
#   • JSON column type: json
#   • These complex types will be properly handled by OLake's pgtype integration

# %%
import subprocess
import time

print("🚀 Starting OLake Sync Process...")
print("="*80)

# Build the sync command
sync_command = [
    ".\\drivers\\postgres\\postgres.exe",
    "sync",
    "--config", "demo_source_config.json",
    "--destination", "demo_destination_config.json",
    "--catalog", "demo_catalog.json"
]

try:
    # Run the sync command
    start_time = time.time()
    result = subprocess.run(
        sync_command,
        capture_output=True,
        text=True,
        timeout=120
    )
    
    elapsed_time = time.time() - start_time
    
    # Display output
    if result.stdout:
        print("📝 Sync Output:")
        print(result.stdout)
    
    if result.returncode == 0:
        print(f"\n✅ Sync completed successfully in {elapsed_time:.2f} seconds!")
    else:
        print(f"\n❌ Sync failed with exit code {result.returncode}")
        if result.stderr:
            print(f"Error: {result.stderr}")
            
except subprocess.TimeoutExpired:
    print("⏱️ Sync command timed out after 120 seconds")
except FileNotFoundError:
    print("⚠️ OLake binary not found. Please ensure postgres.exe is built.")
    print("   Run: cd drivers\\postgres && go build -o postgres.exe .")
except Exception as e:
    print(f"❌ Error running sync: {e}")
# Out:
# 🚀 Starting OLake Sync Process...
# ================================================================================
# 📝 Sync Output:
# 2026-02-10T10:21:13Z INFO Running sync with state: {"type":"STREAM"}
# 2026-02-10T10:21:13Z INFO Standard Replication is selected
# 2026-02-10T10:21:13Z INFO Starting discover for Postgres database postgres
# 2026-02-10T10:21:13Z INFO Valid selected streams are public.test_cdc
# 2026-02-10T10:21:13Z INFO Clearing state for full refresh streams
# 2026-02-10T10:21:13Z INFO Iceberg JAR file found in base directory: c:\Users\diino\Documents\Contributions\olake/olake-iceberg-java-writer.jar
# 2026-02-10T10:21:14Z INFO Thread[iceberg_destination_drop:50051] 05:21:14.973 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Logs will be output to console only
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051] 05:21:15.673 [main] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.io.ResolvingFileIO
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051] 05:21:15.718 [main] INFO  io.debezium.serde.json.JsonSerdeConfig - JsonSerdeConfig values:
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051] 	from.field = null
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051] 	unknown.properties.ignored = false
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051]
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051] 05:21:15.720 [main] INFO  io.debezium.serde.json.JsonSerdeConfig - JsonSerdeConfig values:
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051] 	from.field = null
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051] 	unknown.properties.ignored = false
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051]
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051] 05:21:15.953 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Arrow writer enabled - registered OlakeArrowIngester service
# 2026-02-10T10:21:15Z INFO Thread[iceberg_destination_drop:50051] 05:21:15.963 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Legacy writer enabled - registered OlakeRowsIngester service
# 2026-02-10T10:21:16Z INFO Thread[iceberg_destination_drop:50051] 05:21:16.287 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Server started on port 50051 with max message size: 1024MB
# 2026-02-10T10:21:16Z INFO Thread[iceberg_destination_drop]: Connected to new iceberg writer on port 50051
# 2026-02-10T10:21:16Z INFO Starting Clear Iceberg destination for 1 selected streams
# 2026-02-10T10:21:16Z INFO Dropping Iceberg table: postgres_postgres_public.test_cdc
# 2026-02-10T10:21:16Z INFO Thread[iceberg_destination_drop:50051] 05:21:16.545 [grpc-default-executor-0] WARN  io.debezium.server.iceberg.rpc.OlakeRowsIngester - [Thread-24-8677919902600] Dropping table postgres_postgres_public.test_cdc
# 2026-02-10T10:21:16Z INFO Thread[iceberg_destination_drop:50051] 05:21:16.564 [grpc-default-executor-0] WARN  io.debezium.server.iceberg.IcebergUtil - Table not found: postgres_postgres_public.test_cdc
# 2026-02-10T10:21:16Z INFO Thread[iceberg_destination_drop:50051] 05:21:16.576 [grpc-default-executor-0] WARN  io.debezium.server.iceberg.rpc.OlakeRowsIngester - [Thread-24-8677919902600] Table test_cdc not dropped, table does not exist
# 2026-02-10T10:21:16Z INFO Thread[iceberg_destination_drop:50051] 05:21:16.576 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeRowsIngester - [Thread-24-8677919902600] Total time taken: 32 ms
# 2026-02-10T10:21:16Z INFO Successfully cleared Iceberg destination for selected streams
# 2026-02-10T10:21:16Z INFO Thread[iceberg_destination_drop]: shutting down Iceberg server on port 50051
# 2026-02-10T10:21:16Z INFO Iceberg JAR file found in base directory: c:\Users\diino\Documents\Contributions\olake/olake-iceberg-java-writer.jar
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052] 05:21:18.155 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Logs will be output to console only
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052] 05:21:18.889 [main] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.io.ResolvingFileIO
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052] 05:21:18.923 [main] INFO  io.debezium.serde.json.JsonSerdeConfig - JsonSerdeConfig values:
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052] 	from.field = null
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052] 	unknown.properties.ignored = false
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052]
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052] 05:21:18.924 [main] INFO  io.debezium.serde.json.JsonSerdeConfig - JsonSerdeConfig values:
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052] 	from.field = null
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052] 	unknown.properties.ignored = false
# 2026-02-10T10:21:18Z INFO Thread[test_iceberg_destination:50052]
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052] 05:21:19.089 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Legacy writer enabled - registered OlakeRowsIngester service
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052] 05:21:19.449 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Server started on port 50052 with max message size: 1024MB
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination]: Connected to new iceberg writer on port 50052
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052] 05:21:19.745 [grpc-default-executor-0] WARN  io.debezium.server.iceberg.IcebergUtil - Creating table:'test_olake.test_olake'
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052] schema:table {
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052]   1: _olake_timestamp: optional timestamptz
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052]   2: _op_type: optional string
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052]   3: _olake_id: optional string
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052]   4: data: optional string
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052]   5: _cdc_timestamp: optional timestamptz
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052] }
# 2026-02-10T10:21:19Z INFO Thread[test_iceberg_destination:50052] rowIdentifier:[]
# 2026-02-10T10:21:20Z INFO Thread[test_iceberg_destination:50052] 05:21:20.006 [grpc-default-executor-0] WARN  io.debezium.server.iceberg.IcebergUtil - Created namespace:'test_olake'
# 2026-02-10T10:21:20Z INFO Thread[test_iceberg_destination:50052] 05:21:20.341 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeRowsIngester - [Thread-24-8681079613500] Successfully returned iceberg table test_olake
# 2026-02-10T10:21:20Z INFO Thread[test_iceberg_destination:50052] 05:21:20.342 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeRowsIngester - [Thread-24-8681079613500] Total time taken: 641 ms
# 2026-02-10T10:21:20Z INFO Thread[test_iceberg_destination]: table created or loaded test olake: table {
#   1: _olake_timestamp: optional timestamptz
#   2: _op_type: optional string
#   3: _olake_id: optional string
#   4: data: optional string
#   5: _cdc_timestamp: optional timestamptz
# }
# 2026-02-10T10:21:20Z INFO Thread[test_iceberg_destination:50052] 05:21:20.383 [grpc-default-executor-0] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# 2026-02-10T10:21:21Z INFO Thread[test_iceberg_destination:50052] 05:21:21.986 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.tableoperator.IcebergTableOperator - Successfully wrote 1 events for thread: test_iceberg_destination
# 2026-02-10T10:21:21Z INFO Thread[test_iceberg_destination:50052] 05:21:21.989 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeRowsIngester - [Thread-24-8681740379000] Total time taken: 1625 ms
# 2026-02-10T10:21:21Z DEBUG Thread[test_iceberg_destination]: record inserted successfully: successfully pushed records: 1
# 2026-02-10T10:21:21Z INFO Thread[test_iceberg_destination]: shutting down Iceberg server on port 50052
# 2026-02-10T10:21:22Z INFO Starting backfill for stream[test_cdc] with 1 chunks
# 2026-02-10T10:21:22Z INFO Iceberg JAR file found in base directory: c:\Users\diino\Documents\Contributions\olake/olake-iceberg-java-writer.jar
# 2026-02-10T10:21:23Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:23.717 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Logs will be output to console only
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:24.711 [main] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.io.ResolvingFileIO
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:24.759 [main] INFO  io.debezium.serde.json.JsonSerdeConfig - JsonSerdeConfig values:
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 	from.field = null
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 	unknown.properties.ignored = false
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053]
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:24.762 [main] INFO  io.debezium.serde.json.JsonSerdeConfig - JsonSerdeConfig values:
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 	from.field = null
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 	unknown.properties.ignored = false
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053]
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:24.930 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Arrow writer enabled - registered OlakeArrowIngester service
# 2026-02-10T10:21:24Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:24.937 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Legacy writer enabled - registered OlakeRowsIngester service
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:25.298 [main] INFO  io.debezium.server.iceberg.OlakeRpcServer - Server started on port 50053 with max message size: 1024MB
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37]: Connected to new iceberg writer on port 50053
# 2026-02-10T10:21:25Z INFO Creating destination table [test_cdc] in Iceberg database [postgres_postgres_public] for stream [test_cdc]
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:25.620 [grpc-default-executor-0] WARN  io.debezium.server.iceberg.IcebergUtil - Creating table:'postgres_postgres_public.test_cdc'
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] schema:table {
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053]   1: _op_type: optional string
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053]   2: meta: optional string
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053]   3: id: optional string
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053]   4: data: optional string
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053]   5: created_at: optional timestamptz
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053]   6: _olake_timestamp: optional timestamptz
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053]   7: _olake_id: required string (id)
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] }
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] rowIdentifier:[_olake_id]
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:25.740 [grpc-default-executor-0] WARN  io.debezium.server.iceberg.IcebergUtil - Created namespace:'postgres_postgres_public'
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:25.864 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeRowsIngester - [Thread-24-8686957652999] Successfully returned iceberg table test_cdc
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:25.864 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeRowsIngester - [Thread-24-8686957652999] Total time taken: 283 ms
# 2026-02-10T10:21:25Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:25.909 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeArrowIngester - Loading existing Iceberg table: postgres_postgres_public.test_cdc
# 2026-02-10T10:21:26Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:26.064 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeArrowIngester - [Arrow-24-8687263246200] Total time taken: 179 ms
# 2026-02-10T10:21:26Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37]: created writer for chunk min['(0,0)'] and max['(4294967295,0)'] of stream public.test_cdc
# 2026-02-10T10:21:26Z DEBUG Starting backfill from '(0,0)' to '(4294967295,0)' with filter: , args: []
# 2026-02-10T10:21:26Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37]: successfully wrote 2 records
# 2026-02-10T10:21:26Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:26.114 [grpc-default-executor-0] INFO  org.apache.iceberg.CatalogUtil - Loading custom FileIO implementation: org.apache.iceberg.aws.s3.S3FileIO
# 2026-02-10T10:21:27Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:27.748 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeArrowIngester - [Arrow-24-8687485308400] Successfully uploaded file to: s3://warehouse/postgres_postgres_public/test_cdc/data/20260210-1-d998257f-1a19-4581-85e8-b442cbb049e2-00001.parquet
# 2026-02-10T10:21:27Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:27.749 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeArrowIngester - [Arrow-24-8687485308400] Total time taken: 1640 ms
# 2026-02-10T10:21:28Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:28.232 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.tableoperator.IcebergTableOperator - Thread public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37: accumulated data file s3://warehouse/postgres_postgres_public/test_cdc/data/20260210-1-d998257f-1a19-4581-85e8-b442cbb049e2-00001.parquet (total: 1)
# 2026-02-10T10:21:28Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:28.232 [grpc-default-executor-0] WARN  io.debezium.server.iceberg.tableoperator.IcebergTableOperator - no writer to complete
# 2026-02-10T10:21:28Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:28.233 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.tableoperator.IcebergTableOperator - Committing 1 data files and 0 delete files for thread: public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37
# 2026-02-10T10:21:28Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:28.792 [grpc-default-executor-0] INFO  org.apache.iceberg.SnapshotProducer - Committed snapshot 9153706714926628388 (MergeAppend)
# 2026-02-10T10:21:28Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:28.862 [grpc-default-executor-0] INFO  org.apache.iceberg.metrics.LoggingMetricsReporter - Received metrics report: CommitReport{tableName=demo_catalog.postgres_postgres_public.test_cdc, snapshotId=9153706714926628388, sequenceNumber=1, operation=append, commitMetrics=CommitMetricsResult{totalDuration=TimerResult{timeUnit=NANOSECONDS, totalDuration=PT0.5347672S, count=1}, attempts=CounterResult{unit=COUNT, value=1}, addedDataFiles=CounterResult{unit=COUNT, value=1}, removedDataFiles=null, totalDataFiles=CounterResult{unit=COUNT, value=1}, addedDeleteFiles=null, addedEqualityDeleteFiles=null, addedPositionalDeleteFiles=null, removedDeleteFiles=null, removedEqualityDeleteFiles=null, removedPositionalDeleteFiles=null, totalDeleteFiles=CounterResult{unit=COUNT, value=0}, addedRecords=CounterResult{unit=COUNT, value=2}, removedRecords=null, totalRecords=CounterResult{unit=COUNT, value=2}, addedFilesSizeInBytes=CounterResult{unit=BYTES, value=3909}, removedFilesSizeInBytes=null, totalFilesSizeInBytes=CounterResult{unit=BYTES, value=3909}, addedPositionalDeletes=null, removedPositionalDeletes=null, totalPositionalDeletes=CounterResult{unit=COUNT, value=0}, addedEqualityDeletes=null, removedEqualityDeletes=null, totalEqualityDeletes=CounterResult{unit=COUNT, value=0}}, metadata={iceberg-version=Apache Iceberg 1.7.2 (commit c4e11060db443b0f3e5b70d25e7784f5a8991ad2)}}
# 2026-02-10T10:21:28Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:28.921 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.tableoperator.IcebergTableOperator - Successfully committed 1 data files and 0 delete files for thread: public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37
# 2026-02-10T10:21:28Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37:50053] 05:21:28.922 [grpc-default-executor-0] INFO  io.debezium.server.iceberg.rpc.OlakeArrowIngester - [Arrow-24-8689131810800] Total time taken: 1166 ms
# 2026-02-10T10:21:28Z INFO Thread[public.test_cdc_01KH3H3T6Y9YFHN4DMHZHT3G37]: shutting down Iceberg server on port 50053
# 2026-02-10T10:21:28Z INFO finished chunk min['(0,0)'] and max['(4294967295,0)'] of stream public.test_cdc
# 2026-02-10T10:21:28Z DEBUG state is empty
# 2026-02-10T10:21:28Z DEBUG state is empty
# 2026-02-10T10:21:28Z INFO Total records read: 2
# 2026-02-10T10:21:28Z INFO Sync completed, wait 5 seconds cleanup in progress...
#
#
# ✅ Sync completed successfully in 20.84 seconds!

# %%
from pyiceberg.catalog import load_catalog
import warnings
warnings.filterwarnings('ignore')

# Configure PyIceberg to connect to REST catalog
catalog_config = {
    'uri': 'http://localhost:8181',
    'warehouse': 's3://warehouse/',
    's3.endpoint': 'http://localhost:9090',
    's3.access-key-id': 'minio',
    's3.secret-access-key': 'minio123',
    's3.path-style-access': 'true'
}

try:
    # Load the catalog
    catalog = load_catalog('demo_catalog', **catalog_config)
    print("✓ Connected to Iceberg REST Catalog")
    
    # List namespaces
    namespaces = catalog.list_namespaces()
    print(f"\n📁 Available Namespaces: {namespaces}")
    
    # List tables in the postgres namespace (created by OLake)
    expected_namespace = ('postgres_postgres', 'public')
    try:
        tables = catalog.list_tables(expected_namespace)
        print(f"\n📊 Tables in {expected_namespace}: {tables}")
    except Exception as e:
        print(f"⚠️ Note: {e}")
        print("   Listing all tables in all namespaces...")
        for ns in namespaces:
            try:
                tables = catalog.list_tables(ns)
                if tables:
                    print(f"   {ns}: {tables}")
            except:
                pass
                
except Exception as e:
    print(f"❌ Error connecting to Iceberg catalog: {e}")
    print("\n💡 Alternative: Use Trino or Spark to query Iceberg tables")
    print("   Trino Web UI: http://localhost:8080")
    print("   SQLPad: http://localhost:3000")
# Out:
# ✓ Connected to Iceberg REST Catalog
#
# 📁 Available Namespaces: [('postgres_postgres_public',), ('test_olake',)]
# ⚠️ Note: NoSuchNamespaceException: Namespace does not exist: postgres_postgres.public
#    Listing all tables in all namespaces...
#    ('postgres_postgres_public',): [('postgres_postgres_public', 'test_cdc')]
#    ('test_olake',): [('test_olake', 'test_olake')]

# %%
# Query the synced table
table_id = ('postgres_postgres_public', 'test_cdc')
table = catalog.load_table(table_id)

print(f"✅ Successfully loaded table: {table_id}")
print(f"   Location: {table.location()}")
print(f"   Schema: {table.schema()}\n")

# Query the data
scan = table.scan()
df_iceberg = scan.to_pandas()

print(f"📊 Retrieved {len(df_iceberg)} rows from Iceberg\n")
print("="*80)
display(df_iceberg)

# Store for comparison
globals()['df_iceberg'] = df_iceberg
# Out:
# ✅ Successfully loaded table: ('postgres_postgres_public', 'test_cdc')
#    Location: s3://warehouse/postgres_postgres_public/test_cdc
#    Schema: table {
#   1: created_at: optional timestamptz
#   2: id: optional string
#   3: _olake_timestamp: optional timestamptz
#   4: data: optional string
#   5: _op_type: optional string
#   6: _olake_id: required string
#   7: meta: optional string
# }
#
# 📊 Retrieved 2 rows from Iceberg
#
# ================================================================================
#                         created_at                                    id  \
# 0 2026-02-07 12:54:30.368422+00:00  e61b23d7-2bed-4594-8243-9d389511c688
# 1 2026-02-07 12:54:30.368422+00:00  5f199f4c-cc2b-487c-bbb2-612ffa920e17
#
#                   _olake_timestamp                                   data  \
# 0 2026-02-10 10:23:41.550269+00:00   {"user": "alice", "action": "login"}
# 1 2026-02-10 10:23:41.550269+00:00  {"user": "bob", "action": "purchase"}
#
#   _op_type                             _olake_id                  meta
# 0        r  e61b23d7-2bed-4594-8243-9d389511c688     {"source": "web"}
# 1        r  5f199f4c-cc2b-487c-bbb2-612ffa920e17  {"source": "mobile"}

# %%
# Reconnect to PostgreSQL to get fresh data
conn = psycopg2.connect(**PG_CONFIG)
source_df_compare = pd.read_sql_query(
    "SELECT id::text, data::text, meta::text, created_at FROM test_cdc ORDER BY created_at",
    conn
)
conn.close()

print("🔍 Data Integrity Verification")
print("="*80)

# Compare row counts
source_count = len(source_df_compare)
try:
    dest_count = len(df_iceberg)
    print(f"\n📊 Row Count Comparison:")
    print(f"   Source (PostgreSQL):  {source_count} rows")
    print(f"   Destination (Iceberg): {dest_count} rows")
    
    if source_count == dest_count:
        print("   ✅ Row counts match!")
    else:
        print("   ⚠️ Row count mismatch detected")
    
    # Compare schemas
    print(f"\n📋 Column Comparison:")
    print(f"   Source columns: {list(source_df_compare.columns)}")
    print(f"   Destination columns: {list(df_iceberg.columns)}")
    
    # Sample data comparison
    print(f"\n🔬 Sample Data Verification:")
    print("\nSource (PostgreSQL) - First Row:")
    display(source_df_compare.head(1))
    print("\nDestination (Iceberg) - First Row:")
    display(df_iceberg.head(1))
    
except NameError:
    print("⚠️ Iceberg data not available for comparison")
    print(f"   Source contains {source_count} rows")

print("\n" + "="*80)
print("Complete!")
# Out:
# 🔍 Data Integrity Verification
# ================================================================================
#
# 📊 Row Count Comparison:
#    Source (PostgreSQL):  2 rows
#    Destination (Iceberg): 2 rows
#    ✅ Row counts match!
#
# 📋 Column Comparison:
#    Source columns: ['id', 'data', 'meta', 'created_at']
#    Destination columns: ['created_at', 'id', '_olake_timestamp', 'data', '_op_type', '_olake_id', 'meta']
#
# 🔬 Sample Data Verification:
#
# Source (PostgreSQL) - First Row:
#                                      id                                  data  \
# 0  e61b23d7-2bed-4594-8243-9d389511c688  {"user": "alice", "action": "login"}
#
#                 meta                 created_at
# 0  {"source": "web"} 2026-02-07 12:54:30.368422
# Destination (Iceberg) - First Row:
#                         created_at                                    id  \
# 0 2026-02-07 12:54:30.368422+00:00  e61b23d7-2bed-4594-8243-9d389511c688
#
#                   _olake_timestamp                                  data  \
# 0 2026-02-10 10:23:41.550269+00:00  {"user": "alice", "action": "login"}
#
#   _op_type                             _olake_id               meta
# 0        r  e61b23d7-2bed-4594-8243-9d389511c688  {"source": "web"}
# ================================================================================
# Complete!
